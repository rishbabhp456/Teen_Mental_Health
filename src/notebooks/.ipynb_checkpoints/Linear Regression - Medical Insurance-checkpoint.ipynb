# %% [markdown]
# ### Linear Regression - Medical Insurance Data

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("medical_insurance.csv")
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['gender'].replace({"male":1, "female":0}, inplace = True)
df['smoker'].replace({"yes":1, "no":0}, inplace = True)
df
# Out:
#       age  gender     bmi  children  smoker     region      charges
# 0      19       0  27.900         0       1  southwest  16884.92400
# 1      18       1  33.770         1       0  southeast   1725.55230
# 2      28       1  33.000         3       0  southeast   4449.46200
# 3      33       1  22.705         0       0  northwest  21984.47061
# 4      32       1  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50       1  30.970         3       0  northwest  10600.54830
# 1334   18       0  31.920         0       0  northeast   2205.98080
# 1335   18       0  36.850         0       0  southeast   1629.83350
# 1336   21       0  25.800         0       0  southwest   2007.94500
# 1337   61       0  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df = pd.get_dummies(df, columns=['region'], dtype = int)
df
# Out:
#       age  gender     bmi  children  smoker      charges  region_northeast  \
# 0      19       0  27.900         0       1  16884.92400                 0
# 1      18       1  33.770         1       0   1725.55230                 0
# 2      28       1  33.000         3       0   4449.46200                 0
# 3      33       1  22.705         0       0  21984.47061                 0
# 4      32       1  28.880         0       0   3866.85520                 0
# ...   ...     ...     ...       ...     ...          ...               ...
# 1333   50       1  30.970         3       0  10600.54830                 0
# 1334   18       0  31.920         0       0   2205.98080                 1
# 1335   18       0  36.850         0       0   1629.83350                 0
# 1336   21       0  25.800         0       0   2007.94500                 0
# 1337   61       0  29.070         0       1  29141.36030                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# ...                ...               ...               ...
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
# 1337                 1                 0                 0
#
# [1338 rows x 10 columns]

# %% [markdown]
# ### Train Test Split

# %%
x = df.drop("charges", axis = 1) # 2D
y = df['charges']

# %%
x.shape
# Out:
# (1338, 9)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.80, random_state = 23)
x_train
# Out:
#       age  gender     bmi  children  smoker  region_northeast  \
# 708    31       0  30.495         3       0                 1
# 45     55       1  37.300         0       0                 0
# 434    31       1  28.595         1       0                 0
# 995    39       0  23.275         3       0                 1
# 1299   19       0  25.745         1       0                 0
# ...   ...     ...     ...       ...     ...               ...
# 31     18       0  26.315         0       0                 1
# 950    57       1  18.335         0       0                 1
# 1064   29       0  25.600         4       0                 0
# 742    53       1  34.105         0       1                 1
# 595    46       0  33.725         1       0                 1
#
#       region_northwest  region_southeast  region_southwest
# 708                  0                 0                 0
# 45                   0                 0                 1
# 434                  1                 0                 0
# 995                  0                 0                 0
# 1299                 1                 0                 0
# ...                ...               ...               ...
# 31                   0                 0                 0
# 950                  0                 0                 0
# 1064                 0                 0                 1
# 742                  0                 0                 0
# 595                  0                 0                 0
#
# [1070 rows x 9 columns]

# %%
y_train
# Out:
# 708      6113.23105
# 45      20630.28351
# 434      4243.59005
# 995      7986.47525
# 1299     2710.82855
#            ...
# 31       2198.18985
# 950     11534.87265
# 1064     5708.86700
# 742     43254.41795
# 595      8823.98575
# Name: charges, Length: 1070, dtype: float64

# %%
x_test
# Out:
#      age  gender     bmi  children  smoker  region_northeast  \
# 918   61       0  28.200         0       0                 0
# 755   31       1  27.645         2       0                 1
# 207   35       1  27.740         2       1                 1
# 520   50       0  27.360         0       0                 1
# 695   26       0  40.185         0       0                 0
# ..   ...     ...     ...       ...     ...               ...
# 298   31       1  34.390         3       1                 0
# 369   18       1  30.400         3       0                 1
# 153   42       0  23.370         0       1                 1
# 264   53       0  38.060         3       0                 0
# 359   18       0  20.790         0       0                 0
#
#      region_northwest  region_southeast  region_southwest
# 918                 0                 0                 1
# 755                 0                 0                 0
# 207                 0                 0                 0
# 520                 0                 0                 0
# 695                 1                 0                 0
# ..                ...               ...               ...
# 298                 1                 0                 0
# 369                 0                 0                 0
# 153                 0                 0                 0
# 264                 0                 1                 0
# 359                 0                 1                 0
#
# [268 rows x 9 columns]

# %%
y_test
# Out:
# 918    13041.92100
# 755     5031.26955
# 207    20984.09360
# 520    25656.57526
# 695     3201.24515
#           ...
# 298    38746.35510
# 369     3481.86800
# 153    19964.74630
# 264    20462.99766
# 359     1607.51010
# Name: charges, Length: 268, dtype: float64

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_reg = LinearRegression()
linear_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
linear_reg.coef_
# Out:
# array([  244.58163948,   -93.04516525,   338.44461198,   511.86943511,
#        24000.54812419,   819.80610551,   274.23818994,  -418.87774376,
#         -675.16655168])

# %%
linear_reg.intercept_
# Out:
# -12094.520713632208

# %% [markdown]
# ### Model Evaluation

# %%
x_test[100:105]
# Out:
#      age  gender     bmi  children  smoker  region_northeast  \
# 9     60       0  25.840         0       0                 0
# 993   38       1  28.270         1       0                 0
# 926   19       0  23.400         2       0                 0
# 527   51       0  25.800         1       0                 0
# 26    63       0  23.085         0       0                 1
#
#      region_northwest  region_southeast  region_southwest
# 9                   1                 0                 0
# 993                 0                 1                 0
# 926                 0                 0                 1
# 527                 0                 0                 1
# 26                  0                 0                 0

# %%
y_pred_test = linear_reg.predict(x_test)
y_pred_test[100:105] # Predicted Values
# Out:
# array([11600.02461858,  6767.35729329,   820.70667529,  8947.71677227,
#        11946.92254659])

# %%
y_test[100:105] # Actual
# Out:
# 9      28923.13692
# 993     5484.46730
# 926     2913.56900
# 527     9861.02500
# 26     14451.83515
# Name: charges, dtype: float64

# %%
y_test.shape
# Out:
# (268,)

# %%
y_test
# Out:
# 918    13041.92100
# 755     5031.26955
# 207    20984.09360
# 520    25656.57526
# 695     3201.24515
#           ...
# 298    38746.35510
# 369     3481.86800
# 153    19964.74630
# 264    20462.99766
# 359     1607.51010
# Name: charges, Length: 268, dtype: float64

# %%
error = y_test - y_pred_test
error
# Out:
# 918     1347.990199
# 755    -1563.041669
# 207   -10621.244539
# 520    15442.363310
# 695    -4937.991685
#            ...
# 298     5902.385330
# 369    -1377.166247
# 153   -10942.966656
# 264     5596.758988
# 359     2682.175564
# Name: charges, Length: 268, dtype: float64

# %%
y_test.size
# Out:
# 268

# %%
(error ** 2).sum()
# Out:
# 9286750171.681469

# %%
mse = ((error ** 2).sum())/y_test.size
mse
# Out:
# 34652052.879408464

# %%
rmse = np.sqrt(((error ** 2).sum())/y_test.size)
rmse
# Out:
# 5886.599432559384

# %%
mse = mean_squared_error(y_test, y_pred_test)
mse
# Out:
# 34652052.879408464

# %%
mae = mean_absolute_error(y_test, y_pred_test)
mae
# Out:
# 3991.20379351366

# %% [markdown]
# #### Training data evaluation

# %%
x_train.head(2)
# Out:
#      age  gender     bmi  children  smoker  region_northeast  \
# 708   31       0  30.495         3       0                 1
# 45    55       1  37.300         0       0                 0
#
#      region_northwest  region_southeast  region_southwest
# 708                 0                 0                 0
# 45                  0                 0                 1

# %%
y_pred_train = linear_reg.predict(x_train)
y_pred_train.size
# Out:
# 1070

# %%
mse = mean_squared_error(y_train, y_pred_train)
mse
# Out:
# 37056761.48533833

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 6087.426507592378

# %% [markdown]
# #### R-squared Error

# %%
r2_train = r2_score(y_train, y_pred_train)
r2_train
# Out:
# 0.7493255146273343

# %%
r2_test = r2_score(y_test, y_pred_test)
r2_test
# Out:
# 0.7536440382001555

# %% [markdown]
# ### Training Data Evaluation

# %%
y_pred_train = linear_reg.predict(x_train)

mse = mean_squared_error(y_train, y_pred_train)
print("MSE :",mse)

rmse = np.sqrt(mse)
print("RMSE :",rmse)

mae = mean_absolute_error(y_train, y_pred_train)
print("MAE :",mae)

r2_train = r2_score(y_train, y_pred_train)
print("R-squared :",r2_train)
# Out:
# MSE : 37056761.48533833
# RMSE : 6087.426507592378
# MAE : 4212.153489540198
# R-squared : 0.7493255146273343

# %%
y_train
# Out:
# 708      6113.23105
# 45      20630.28351
# 434      4243.59005
# 995      7986.47525
# 1299     2710.82855
#            ...
# 31       2198.18985
# 950     11534.87265
# 1064     5708.86700
# 742     43254.41795
# 595      8823.98575
# Name: charges, Length: 1070, dtype: float64

# %%
pd.Series(y_pred_train)
# Out:
# 0        8163.792963
# 1       13213.241768
# 2        5858.396250
# 3        7676.875981
# 4        2051.894597
#             ...
# 1065     2033.924867
# 1066     8778.775638
# 1067     5034.840087
# 1068    37138.268735
# 1069    11901.954782
# Length: 1070, dtype: float64

# %%
error = y_train - y_pred_train
error
# Out:
# 708    -2050.561913
# 45      7417.041742
# 434    -1614.806200
# 995      309.599269
# 1299     658.933953
#            ...
# 31       164.264983
# 950     2756.097012
# 1064     674.026913
# 742     6116.149215
# 595    -3077.969032
# Name: charges, Length: 1070, dtype: float64

# %% [markdown]
# #### Testing data evaluation

# %%
y_pred_test = linear_reg.predict(x_test)

mse = mean_squared_error(y_test, y_pred_test)
print("MSE :",mse)

rmse = np.sqrt(mse)
print("RMSE :",rmse)

mae = mean_absolute_error(y_test, y_pred_test)
print("MAE :",mae)

r2_test = r2_score(y_test, y_pred_test)
print("R-squared :",r2_test)
# Out:
# MSE : 34652052.879408464
# RMSE : 5886.599432559384
# MAE : 3991.20379351366
# R-squared : 0.7536440382001555

# %% [markdown]
# ### Save model

# %%
import pickle
with open("linear_reg_med_ins.pkl", "wb") as f:
    pickle.dump(linear_reg, f)

# %%
R2 = 0.9
VIF = 1/(1-R2)
VIF
# Out:
# 10.000000000000002

# %%
R2 = 0
VIF = 1/(1-R2)
VIF
# Out:
# 1.0

# %%
R2 = 0.2
VIF = 1/(1-R2)
VIF
# Out:
# 1.25

# %%
R2 = 0.5
VIF = 1/(1-R2)
VIF
# Out:
# 2.0

# %%
R2 = 0.7
VIF = 1/(1-R2)
VIF
# Out:
# 3.333333333333333

# %%
R2 = 0.99
VIF = 1/(1-R2)
VIF
# Out:
# 99.99999999999991

# %%
R2 = 0.987654
VIF = 1/(1-R2)
VIF
# Out:
# 80.99789405475478

# %% [markdown]
# ### Normality of Residual

# %%
error = y_test - y_pred_test
error
# Out:
# 918     1347.990199
# 755    -1563.041669
# 207   -10621.244539
# 520    15442.363310
# 695    -4937.991685
#            ...
# 298     5902.385330
# 369    -1377.166247
# 153   -10942.966656
# 264     5596.758988
# 359     2682.175564
# Name: charges, Length: 268, dtype: float64

# %%
error = y_train - y_pred_train
error
# Out:
# 708    -2050.561913
# 45      7417.041742
# 434    -1614.806200
# 995      309.599269
# 1299     658.933953
#            ...
# 31       164.264983
# 950     2756.097012
# 1064     674.026913
# 742     6116.149215
# 595    -3077.969032
# Name: charges, Length: 1070, dtype: float64

# %%
sns.histplot(error)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot(error, kde = True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.kdeplot(error)
# Out:
# <Axes: xlabel='charges', ylabel='Density'>

# %%
error.skew()
# Out:
# 1.184403156465042

# %% [markdown]
# ### Hypothesis Testing

# %%
from scipy.stats import shapiro, normaltest, kstest

# %%
stats, p_val = shapiro(error)
print("p value :", p_val)
if p_val >= 0.05:
    print("Data is normally distributed")

else:
    print("data is not normally distributed")
# Out:
# p value : 1.8317495665461294e-25
# data is not normally distributed

# %%
array = np.random.randn(15000)

stats, p_val = shapiro(array)
print("p value :", p_val)
if p_val >= 0.05:
    print("Data is normally distributed")

else:
    print("data is not normally distributed")

sns.kdeplot(array)
# Out:
# p value : 0.6084540486335754
# Data is normally distributed
# <Axes: ylabel='Density'>

# %%
array = np.random.randn(15000)

stats, p_val = normaltest(array)
print("p value :", p_val)
if p_val >= 0.05:
    print("Data is normally distributed")

else:
    print("data is not normally distributed")

sns.kdeplot(array)
# Out:
# p value : 0.3838405573949335
# Data is normally distributed
# <Axes: ylabel='Density'>

# %%
# array = np.random.randn(15000)

stats, p_val = normaltest(error)
print("p value :", p_val)
if p_val >= 0.05:
    print("Data is normally distributed")

else:
    print("data is not normally distributed")

# sns.kdeplot(array)
# Out:
# p value : 7.210354841114538e-52
# data is not normally distributed

# %%
stats, p_val = kstest(error, 'norm')
print("p value :", p_val)
if p_val >= 0.05:
    print("Data is normally distributed")

else:
    print("data is not normally distributed")
# Out:
# p value : 0.0
# data is not normally distributed

# %% [markdown]
# ### QQplot

# %%
from scipy.stats import probplot

# %%
import statsmodels.api as sm

# %%
sm.qqplot(error, line = '45')

# %%
sm.qqplot(array, line = '45')

# %%
array = np.random.randn(250)
sm.qqplot(array, line = '45')
plt.savefig("QQPlot.png")

# %% [markdown]
# ### 4. Homoscedasticity

# %%
y_pred_train
# Out:
# array([ 8163.79296333, 13213.24176757,  5858.39624953, ...,
#         5034.84008666, 37138.26873472, 11901.95478199])

# %%
error
# Out:
# 708    -2050.561913
# 45      7417.041742
# 434    -1614.806200
# 995      309.599269
# 1299     658.933953
#            ...
# 31       164.264983
# 950     2756.097012
# 1064     674.026913
# 742     6116.149215
# 595    -3077.969032
# Name: charges, Length: 1070, dtype: float64

# %%
sns.scatterplot(x = y_pred_train,y=  error)
# Out:
# <Axes: ylabel='charges'>

# %% [markdown]
# ### Save Columns Data

# %%
import json

# %%
df['gender'].replace({"male":1, "female":0}, inplace = True)
df['smoker'].replace({"yes":1, "no":0}, inplace = True)
df
# Out:
#       age  gender     bmi  children  smoker      charges  region_northeast  \
# 0      19       0  27.900         0       1  16884.92400                 0
# 1      18       1  33.770         1       0   1725.55230                 0
# 2      28       1  33.000         3       0   4449.46200                 0
# 3      33       1  22.705         0       0  21984.47061                 0
# 4      32       1  28.880         0       0   3866.85520                 0
# ...   ...     ...     ...       ...     ...          ...               ...
# 1333   50       1  30.970         3       0  10600.54830                 0
# 1334   18       0  31.920         0       0   2205.98080                 1
# 1335   18       0  36.850         0       0   1629.83350                 0
# 1336   21       0  25.800         0       0   2007.94500                 0
# 1337   61       0  29.070         0       1  29141.36030                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# 2                    0                 1                 0
# 3                    1                 0                 0
# 4                    1                 0                 0
# ...                ...               ...               ...
# 1333                 1                 0                 0
# 1334                 0                 0                 0
# 1335                 0                 1                 0
# 1336                 0                 0                 1
# 1337                 1                 0                 0
#
# [1338 rows x 10 columns]

# %%
med_ins_json = {"gender" : {"male":1, "female":0},
                "smoker" : {"yes":1, "no":0}, 
               "colName" : list(linear_reg.feature_names_in_)}
med_ins_json
# Out:
# {'gender': {'male': 1, 'female': 0},
#  'smoker': {'yes': 1, 'no': 0},
#  'colName': ['age',
#   'gender',
#   'bmi',
#   'children',
#   'smoker',
#   'region_northeast',
#   'region_northwest',
#   'region_southeast',
#   'region_southwest']}

# %%
with open("med_ins_column_data.json", "w") as f:
    json.dump(med_ins_json, f)

# %%
linear_reg.feature_names_in_
# Out:
# array(['age', 'gender', 'bmi', 'children', 'smoker', 'region_northeast',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype=object)

# %%
linear_reg.n_features_in_
# Out:
# 9
